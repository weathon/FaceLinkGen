# %%
import os
path = "training-tpdne"
new_path = "cropped-training-tpdne"
os.makedirs(new_path, exist_ok=True)

# %%
# %pip install tf-keras -qq

# %%
from deepface import DeepFace
import os
import matplotlib.pyplot as plt
imgs = os.listdir(path)
imgs = [os.path.join(path, i) for i in imgs]
# Out:
# 2025-12-23 20:48:42.913267: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-23 20:48:42.975588: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-23 20:48:44.749438: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# import pylab
# from PIL import Image
# for i in range(len(imgs)):
#     img = DeepFace.extract_faces(imgs[i], detector_backend = "ssd")
#     Image.fromarray((img[0]["face"]*255).astype("uint8")).save(os.path.join(new_path, os.path.basename(imgs[i])))

# %%
import os
root = '/path/to/casia-webface/004011'
images = [os.path.join(root, i) for i in os.listdir(root)]

# %%
from deepface import DeepFace

# %%
from deepface import DeepFace
from PIL import Image
import pylab 
pylab.subplot(1, 2, 1)
pylab.imshow(Image.open(images[0]))
pylab.subplot(1, 2, 2)
pylab.imshow(DeepFace.extract_faces(images[0], detector_backend = "opencv")[0]["face"])

# %%
DeepFace.extract_faces(images[0], detector_backend = "opencv")[0]["face"]
# Out:
# array([[[0.62352941, 0.63921569, 0.65882353],
#         [0.62352941, 0.63529412, 0.65490196],
#         [0.62352941, 0.63529412, 0.65490196],
#         ...,
#         [0.26666667, 0.25882353, 0.2745098 ],
#         [0.59607843, 0.58431373, 0.60784314],
#         [0.68627451, 0.67843137, 0.70196078]],
#
#        [[0.62745098, 0.63921569, 0.65882353],
#         [0.62745098, 0.63921569, 0.65882353],
#         [0.62745098, 0.63921569, 0.65882353],
#         ...,
#         [0.19215686, 0.18823529, 0.2       ],
#         [0.50980392, 0.50980392, 0.52156863],
#         [0.65882353, 0.65490196, 0.6745098 ]],
#
#        [[0.62745098, 0.63921569, 0.65882353],
#         [0.62745098, 0.63921569, 0.65882353],
#         [0.61960784, 0.63137255, 0.65098039],
#         ...,
#         [0.15686275, 0.15686275, 0.16470588],
#         [0.46666667, 0.46666667, 0.4745098 ],
#         [0.66666667, 0.6627451 , 0.67843137]],
#
#        ...,
#
#        [[0.11372549, 0.11764706, 0.13333333],
# ...
