# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torchbenchmark.models.densenet121
#       2 model, example_inputs = torchbenchmark.models.densenet121.Model(test="eval", device="cuda:0", batch_size=1).get_module()
#       3 model(*example_inputs)
#
# File ~/miniconda/envs/py311/lib/python3.11/site-packages/torchbenchmark/__init__.py:64
#      60         os.environ = self.os_environ.copy()
#      63 with add_path(str(REPO_PATH)):
# ---> 64     from utils import get_pkg_versions, TORCH_DEPS
#      66 this_dir = pathlib.Path(__file__).parent.absolute()
#      67 model_dir = "models"
#
# ModuleNotFoundError: No module named 'utils'
